# %%
a = "Geekforgeeks"
upper = lambda x:x.upper()
print(upper(a))
# Out:
# GEEKFORGEEKS

# %%
check = lambda x: "positive" if x> 0 else "negative" if x<0 else "zero"

# %%
func = [ lambda arg = x: arg for x in range(1,5)]
for i in func:
    print(i())
# Out:
# 1
# 2
# 3
# 4

# %%
calc = lambda x,y: (x+y,x*y)
res = calc(3,4)
print(res)
# Out:
# (7, 12)

# %%
c=  [1 ,2,3,4,5,6]
even = filter(lambda x:x%2==0,c)
print(list(even))
# Out:
# [2, 4, 6]

# %%
# map
a = [1,2,3,4,5]
double = map(lambda x: x*2,a)
print(list(double))
# Out:
# [2, 4, 6, 8, 10]

# %%
# reduce()
from functools import reduce
a  = [1,2,3,4,5]
mul = reduce(lambda x,y:x*y,a)
print(mul)
# Out:
# 120
