# %% [markdown]
# validation được sử dụng để kiểm tra xem mô hình có đi đúng hướng hay không, nếu mô hình đang đi đúng hướng thì loss function của epoch 1 phải lớn hơn epoch 2
# do đó validation không được sử dụng để đánh giá mô hình mà chỉ là để kiểm tra mô hình
# -> cần test set để kiểm tra mô hình
# test set để đánh giá perf cuối cùng của mình
#
#
# số lượng dữ liệu càng ít thì càng phải chia cho (training) nhiều
# ví dụ nếu dataset nhiều thì nên chia 60 20 20
# vừa phải thì nên chia 70 15 15
# còn nếu dataset ít thì 80 10 10
#
#
# classification( phân loại ): dự đoán nhãn không liên tục, ví dụ dự đoán là chó mèo lợn gà, không liên tục
# regression ( hồi quy ):dự đoán nhãn liên tục, ví dụ dự đoán giá nhà, giá hàng hoá, số ngẫu nhiên trong R

# %%
##### classification: Cách đnahs giá mô hình trong Supervised Learning
để biết mô hình tốt hay tồi thì phải biết đánh giá nó

giả sử với bài classification với đánh giá dự đoán chó mèo
để đnahs giá tốt xấu của mô hình này có những metric nào: 
accuracy, f1, recall, precision, 
acc = (tp + tn )/ n tổng số lần dự đoán đúng / tổng số dự đoán
p = tp/(tp+fp)  số lần dự đoán positive đúng / tổng số lần dự đoán positive ( số làn dự đoán positive đúng trong số lần dự đoán positive)
recall = tp/(tp+fn) : 

 trong số từng này người bị covid tôi tìm ra được bao nhiêu người thì đấy là recall
 trong số từng này người tôi bảo bị covid thì có bao nhiêu người thực sự bị thì đó là precision 



 metric:
 true positive rate = recall : tp/(tp+fn)
 false positive rate : fp / (fp+tn)
