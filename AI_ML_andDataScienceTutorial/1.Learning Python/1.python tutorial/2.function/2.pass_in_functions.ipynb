# %%
# the pass statement in python is a placeholder that does nothing when excuted.

# %%
def fun():
    pass
fun()
# Out:
# <function __main__.fun()>

# %%
def fun(a):
    if a>10 :
        pass
    else:
        print("ok")

b= int(input("input: "))
fun(b)
# Out:
# ok

# %%
"""
IN loops
"""

for i in range(5):
    if i==3:
        pass
    else:
        print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
"""
in classes
"""
class EmptyClass:
    pass

class person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def greet(self):
        pass

p = person("emily", 10)
